# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

# %%
Data=pd.read_csv('AllData.csv')

# %%
Data.head()
# Out:
#    Unnamed: 0  Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0           0   1          60         65.0   8450.0          7.0            5
# 1           1   2          20         80.0   9600.0          6.0            8
# 2           2   3          60         68.0  11250.0          7.0            5
# 3           3   4          70         60.0   9550.0          7.0            5
# 4           4   5          60         84.0  14260.0          8.0            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ...  SaleType_ConLw  SaleType_New  \
# 0     2003.0          2003       200.0  ...               0             0
# 1     1976.0          1976         0.0  ...               0             0
# 2     2001.0          2002       200.0  ...               0             0
# 3     1920.0          1970         0.0  ...               0             0
# 4     2000.0          2000       400.0  ...               0             0
#
# ...

# %%
Data=Data.drop('Unnamed: 0', axis=1)

# %%
Data.head(3)
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0   8450.0          7.0            5     2003.0
# 1   2          20         80.0   9600.0          6.0            8     1976.0
# 2   3          60         68.0  11250.0          7.0            5     2001.0
#
#    YearRemodAdd  MasVnrArea  ExterQual  ...  SaleType_ConLw  SaleType_New  \
# 0          2003       200.0          4  ...               0             0
# 1          1976         0.0          3  ...               0             0
# 2          2002       200.0          4  ...               0             0
#
#    SaleType_Oth  SaleType_WD  SaleCondition_Abnorml  SaleCondition_AdjLand  \
# 0             0            1                      0                      0
# 1             0            1                      0                      0
# 2             0            1                      0                      0
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X=Data.drop(['Id', 'SalePrice'], axis=1)
Y=Data['SalePrice']

# %%
X_train=X[:2400]
X_test=X[2400:]

y_train=Y[:2400]
y_test=Y[2400:]

# %%
## Normalize Data

X_train_norm=(X_train-X_train.min())/(X_train.max()-X_train.min())

# %%
X=Norm.drop(['Id', 'SalePrice'], axis=1)
Y=Data['SalePrice']

# %%
X_train.isnull().values.any()
# Out:
# False

# %%
def build_model(n_hidden=1, n_neurons=250, learning_rate=0.05, input_shape=[250]):
    model=keras.models.Sequential()
    model.add(keras.layers.InputLayer(input_shape=input_shape))
    for layer in range(n_hidden):
        model.add(keras.layers.Dense(n_neurons, activation="relu"))
    model.add(keras.layers.Dense(1))
    optimizer= keras.optimizers.SGD(lr=learning_rate)
    model.compile(loss="mae", optimizer=optimizer)
    return model

# %%
regressor= keras.wrappers.scikit_learn.KerasRegressor(build_model)

# %%
regressor.fit(X_train, y_train, epochs=70, batch_size=24)
# Out:
# Epoch 1/70
# 100/100 [==============================] - 0s 2ms/step - loss: 145065607430144.0000
# Epoch 2/70
# 100/100 [==============================] - 0s 1ms/step - loss: 110058.9531
# Epoch 3/70
# 100/100 [==============================] - 0s 1ms/step - loss: 110058.7031
# Epoch 4/70
# 100/100 [==============================] - 0s 2ms/step - loss: 110058.4922
# Epoch 5/70
# 100/100 [==============================] - 0s 2ms/step - loss: 110058.2422
# Epoch 6/70
# 100/100 [==============================] - 0s 2ms/step - loss: 110057.9844
# Epoch 7/70
# 100/100 [==============================] - 0s 2ms/step - loss: 110057.7969
# Epoch 8/70
# 100/100 [==============================] - 0s 2ms/step - loss: 110057.5156
# Epoch 9/70
# 100/100 [==============================] - 0s 2ms/step - loss: 110057.3125
# Epoch 10/70
# 100/100 [==============================] - 0s 2ms/step - loss: 110057.0859
# Epoch 11/70
# ...
